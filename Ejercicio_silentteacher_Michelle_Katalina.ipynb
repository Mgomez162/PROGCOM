# %%
class Pregunta:
    def __init__(self, enunciado, opciones, respuesta_correcta):
        self.enunciado = enunciado
        self.opciones = opciones
        self.respuesta_correcta = respuesta_correcta

    def mostrar_pregunta(self):
        print(self.enunciado)
        for idx, opcion in enumerate(self.opciones, 1):
            print(f"{idx}. {opcion}")

    def es_correcta(self, respuesta_usuario):
        # Verifica si el índice de la respuesta coincide con la respuesta correcta
        return self.opciones[respuesta_usuario - 1] == self.respuesta_correcta
class Evaluacion:
    def __init__(self):
        self.preguntas = []

    def agregar_pregunta(self, pregunta):
        self.preguntas.append(pregunta)

    def evaluar_respuesta(self, pregunta, respuesta_usuario):
        if pregunta.es_correcta(respuesta_usuario):
            print("¡Correcto!")
        else:
            print(f"Incorrecto. La respuesta correcta era: {pregunta.respuesta_correcta}")

    def realizar_evaluacion(self):
        for pregunta in self.preguntas:
            pregunta.mostrar_pregunta()
            respuesta_usuario = int(input("Selecciona la opción correcta (número): "))
            self.evaluar_respuesta(pregunta, respuesta_usuario)
# Crear preguntas
pregunta1 = Pregunta(
    "¿Qué es el encapsulamiento?",
    ["Ocultar datos de los usuarios", "Agrupar métodos y atributos", "Hacer que los datos sean públicos"],
    "Ocultar datos de los usuarios"
)

pregunta2 = Pregunta(
    "¿Cuál es el principal beneficio del encapsulamiento?",
    ["Mayor seguridad", "Menor complejidad", "Código más corto"],
    "Mayor seguridad"
)

pregunta3 = Pregunta(
    "¿Qué son los métodos getter?",
    ["Métodos para acceder a atributos privados", "Métodos para modificar atributos", "Métodos de inicialización"],
    "Métodos para acceder a atributos privados"
)

pregunta4 = Pregunta(
    "¿Cómo se nombran comúnmente los métodos getter?",
    ["getNombre", "NombreGet", "obtenerNombre"],
    "getNombre"
)

pregunta5 = Pregunta(
    "¿Por qué es importante el encapsulamiento en POO?",
    ["Facilita el mantenimiento", "Aumenta la velocidad", "Elimina errores"],
    "Facilita el mantenimiento"
)

pregunta6 = Pregunta(
    "¿El encapsulamiento garantiza que los datos sean completamente seguros?",
    ["Sí", "No", "Solo en algunos casos"],
    "No"
)

pregunta7 = Pregunta(
    "¿Qué significa private?",
    ["Acceso restringido", "Acceso público", "Acceso interno"],
    "Acceso restringido"
)

pregunta8 = Pregunta(
    "¿Cuáles son los tres niveles de acceso para el encapsulamiento?",
    ["Public, Protected, Private", "Visible, Invisible, Protected", "Interno, Externo, Público"],
    "Public, Protected, Private"
)

pregunta9 = Pregunta(
    "¿Qué miembros de una clase suelen estar encapsulados?",
    ["Atributos", "Métodos", "Ambos"],
    "Atributos"
)

# Crear evaluación
evaluacion = Evaluacion()
evaluacion.agregar_pregunta(pregunta1)
evaluacion.agregar_pregunta(pregunta2)
evaluacion.agregar_pregunta(pregunta3)
evaluacion.agregar_pregunta(pregunta4)
evaluacion.agregar_pregunta(pregunta5)
evaluacion.agregar_pregunta(pregunta6)
evaluacion.agregar_pregunta(pregunta7)
evaluacion.agregar_pregunta(pregunta8)
evaluacion.agregar_pregunta(pregunta9)

# Realizar evaluación
evaluacion.realizar_evaluacion()

# %%
class Pregunta:
    def __init__(self, enunciado, opciones, respuesta_correcta):
        self.enunciado = enunciado
        self.opciones = opciones
        self.respuesta_correcta = respuesta_correcta

    def mostrar_pregunta(self):
        print(self.enunciado)
        for idx, opcion in enumerate(self.opciones, 1):
            print(f"{idx}. {opcion}")

    def es_correcta(self, respuesta_usuario):
        return self.opciones[respuesta_usuario - 1] == self.respuesta_correcta
class Evaluacion:
    def __init__(self):
        self.preguntas = []

    def agregar_pregunta(self, pregunta):
        self.preguntas.append(pregunta)

    def evaluar_respuesta(self, pregunta, respuesta_usuario):
        if pregunta.es_correcta(respuesta_usuario):
            print("¡Correcto!")
        else:
            print(f"Incorrecto. La respuesta correcta era: {pregunta.respuesta_correcta}")

    def realizar_evaluacion(self):
        for pregunta in self.preguntas:
            pregunta.mostrar_pregunta()
            respuesta_usuario = int(input("Selecciona la opción correcta (número): "))
            self.evaluar_respuesta(pregunta, respuesta_usuario)
# Crear preguntas sobre abstracción
pregunta1 = Pregunta(
    "¿Qué es la abstracción en POO?",
    ["Ocultar detalles innecesarios", "Implementar interfaces gráficas", "Reducir el tamaño del código"],
    "Ocultar detalles innecesarios"
)

pregunta2 = Pregunta(
    "¿Cuál es la diferencia entre abstracción y encapsulamiento?",
    ["Abstracción oculta información, encapsulamiento oculta implementación",
     "Ambas son lo mismo",
     "Encapsulamiento se refiere a clases, abstracción a objetos"],
    "Abstracción oculta información, encapsulamiento oculta implementación"
)

pregunta3 = Pregunta(
    "¿Qué es una clase abstracta?",
    ["Clase que no se puede instanciar", "Clase que contiene solo métodos concretos", "Clase que no tiene atributos"],
    "Clase que no se puede instanciar"
)

pregunta4 = Pregunta(
    "¿Qué es un método abstracto?",
    ["Método que no tiene implementación", "Método que no se puede usar", "Método que solo se usa en la clase madre"],
    "Método que no tiene implementación"
)

pregunta5 = Pregunta(
    "¿Qué es la abstracción de datos?",
    ["Ocultar datos complejos", "Mostrar todos los detalles", "Sustituir datos por otros"],
    "Ocultar datos complejos"
)

pregunta6 = Pregunta(
    "¿Puede una clase abstracta tener constructor?",
    ["Sí", "No", "Solo si tiene métodos abstractos"],
    "Sí"
)

pregunta7 = Pregunta(
    "¿Por qué es importante la abstracción en el diseño?",
    ["Facilita el entendimiento", "Reduce la cantidad de código", "Aumenta la velocidad de ejecución"],
    "Facilita el entendimiento"
)

pregunta8 = Pregunta(
    "¿Por qué usar abstracción en vez de clases concretas?",
    ["Para evitar la sobrecarga de detalles", "Para hacer el código más largo", "Para aumentar la complejidad"],
    "Para evitar la sobrecarga de detalles"
)

pregunta9 = Pregunta(
    "¿Una clase puede heredar de múltiples clases abstractas?",
    ["Sí", "No", "Solo en lenguajes específicos"],
    "Sí"
)

pregunta10 = Pregunta(
    "¿Cuál es el nivel de abstracción más alto?",
    ["Interfaz", "Clase abstracta", "Clase concreta"],
    "Interfaz"
)

# Crear evaluación
evaluacion = Evaluacion()
evaluacion.agregar_pregunta(pregunta1)
evaluacion.agregar_pregunta(pregunta2)
evaluacion.agregar_pregunta(pregunta3)
evaluacion.agregar_pregunta(pregunta4)
evaluacion.agregar_pregunta(pregunta5)
evaluacion.agregar_pregunta(pregunta6)
evaluacion.agregar_pregunta(pregunta7)
evaluacion.agregar_pregunta(pregunta8)
evaluacion.agregar_pregunta(pregunta9)
evaluacion.agregar_pregunta(pregunta10)

# Realizar evaluación
evaluacion.realizar_evaluacion()
